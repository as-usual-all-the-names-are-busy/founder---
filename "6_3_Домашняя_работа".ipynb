# %% [markdown]
# ## Задача 1. Книги без буквы E.

# %% [markdown]
# **Условие.** В истории литературы известен случай написания романа объемом около
# 50 тыс. слов, в котором ни разу не была употреблена самая популярная
# в английском алфавите буква E. Название его – «Gadsby».
# Напишите программу, которая будет считывать список слов из файла и собирать статистику о том, в каком проценте слов используется каждая буква алфавита. Выведите результат для всех 26 букв английского алфавита и отдельно отметьте букву, которая встречалась в словах наиболее редко. В  вашей программе должны игнорироваться знаки препинания и регистр символов.

# %% [markdown]
# **Подсказки.**
# 1. Переведите все слова в верхний регистр:
# ```
# word = word.upper().rstrip() # upper - переводит строку в верхний регистр
# ```
# 2. Создайте словарь со счетчиком слов, содержащий каждую букву
# ```
# # Для каждой буквы инициализируем счетчик нулем
# counts = {}
# for ch in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
#        counts[ch] = 0
# ```
# 3. Наиболее редко используемые буквы можно найти следующим образом:
# ```
# smallest_count = min(counts.values()) # min - возвращает наименьшее число в списке
# ```

# %%
with open('input.txt', 'w') as file:
    file.write('''first string\nsecond string\n25458\n13:00\nthird string\nfours string\nand one\nand one\nand enough''')

counts = {}
for i in "ABCDEFGHIJKLMNOPQRSTUVWXYZ":
    counts[i] = 0

len_words = 0

with open('input.txt') as file:
    for string in file.readlines():
        string = string.strip().upper().split()
        string = list(filter(lambda i: i.isalpha(), string)) # по сути добавил только эту строчку
        len_words += len(string)
        for word in string:
            for ch in word.strip(', .:;!?'):
                counts[ch] = counts[ch] + 1

word_0 = ", ".join([i for i in counts if counts[i] == 0])
word_not_0 = [i for i in counts if counts[i] != 0]

print(f'{word_0} - эти буквы не встречаются вовсе')
print('процентное содержание остальных букв:')
for i in word_not_0:
    print(f'{i} - {int(counts[i]*100/len_words)}%')
# Out:
# B, J, K, L, M, P, Q, V, W, X, Y, Z - эти буквы не встречаются вовсе
# процентное содержание остальных букв:
# A - 21%
# C - 7%
# D - 35%
# E - 28%
# F - 14%
# G - 35%
# H - 14%
# I - 42%
# N - 78%
# O - 35%
# R - 50%
# S - 50%
# T - 42%
# U - 14%

# %% [markdown]
# ## Задание 2. Веб-скрейпинг ИИ новостей

# %% [markdown]
# **Описание задания.** Используя пример веб-скрейпинга практической части урока, проведите скрейпинг сайта с новостями из сферы ИИ (https://2051.vision/category/ii/), выведите на экран заголовки новостей.

# %%
from bs4 import BeautifulSoup as bs
from requests import get

url = r'https://2051.vision/category/ii/'
html = get(url).text
soup = bs(html, 'html5lib')

for i in soup.find_all(class_='entry-title'): # а откуда взялсь этот 'entry-title' ? как понять откуда его брать? вниз кинул скрин
    print(i.text.strip())
# Out:
# Антон Балыклов: «Важно, как вы используете ИИ в своей деятельности и для каких целей, поскольку одноразовый хайп в современном мире не эффективен»
# ИИ впервые прошел тест Тьюринга
# Системы интеллектуальной видеоаналитики
# Apple в тренде: компания показала собственную ИИ-систему
# Нейросеть получила задание заглянуть в будущее
# ЕС учредил Управление по ИИ — контролирующий орган в сфере искусственного интеллекта
# OpenAI приступила к обучению следующего поколения ИИ-моделей
# За дипфейки хотят ввести уголовную ответственность
# Чат-боты загоняют нас в информационный пузырь
# O for Omni: OpenAI показала новую ChatGPT
# Виктория Кириченко: «Наш отдел занимается медицинским обеспечением космических полетов»
# Огонь, вода и друг шахтера: как начиналась эпоха пара
# Тест. Дирижабли: какими они были?
# Бионический протез с нейроинтерфейсом обеспечит удивительную подвижность людям с ампутированной конечностью

# %% [markdown]
# ![image.png](data:image/png;base64,...)
