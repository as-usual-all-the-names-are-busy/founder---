# %% [markdown]
# ## Задача 1. Приветствие.

# %% [markdown]
# **Условие.** Напишите программу, запрашивающую у пользователя его имя. В ответ
# на ввод на экране должно появиться приветствие с обращением по имени,
# введенному с клавиатуры ранее.

# %%
# свое решение
name = input('напиши как тебя зовут? :  ')
print(f'Здравствуй {name} ! Будем знакомы !')
# Out:
# напиши как тебя зовут? :  Василий
# Здравствуй Василий ! Будем знакомы !

# %% [markdown]
# ## Задача 2. Сувениры и безделушки.

# %% [markdown]
# **Условие.** Интернет-магазин занимается продажей различных сувениров и безделушек. Каждый сувенир весит 75 г, а безделушка – 112 г. Напишите программу, запрашивающую у пользователя количество тех и других покупок,
# после чего выведите на экран общий вес посылки.

# %%
#свое решение
wps = 75
wpb = 112
print(f"Общий вес посылки: {int(input('сколько сувениров: ')) * wps + int(input('сколько безделушек: ')) * wpb} г")
# Out:
# сколько сувениров: 4
# сколько безделушек: 5
# Общий вес посылки: 860 г

# %% [markdown]
# ## Задача 3. Сложные проценты

# %% [markdown]
# **Условие.** Представьте, что вы открыли в банке сберегательный счет под 4 % годовых. Проценты банк рассчитывает в конце года и добавляет к сумме счета.
# Напишите программу, которая запрашивает у пользователя сумму первоначального депозита, после чего рассчитывает и выводит на экран сумму
# на счету в конце первого, второго и третьего годов. Все суммы должны
# быть округлены до двух знаков после запятой.

# %%
#свое решение
bonus = 4
s_0 = float(input('сумма первоначального депозита: '))
s_1 = s_0 + (s_0 * bonus / 100)
s_2 = s_1 + (s_1 * bonus / 100)
s_3 = s_2 + (s_2 * bonus / 100)
print('сумму на счету в конце первого года: %.2f' % s_1)
print('сумму на счету в конце второго года: %.2f' % s_2)
print('сумму на счету в конце третьего года: %.2f' % s_3)
# Out:
# сумма первоначального депозита: 250000
# сумму на счету в конце первого года: 260000.00
# сумму на счету в конце второго года: 270400.00
# сумму на счету в конце третьего года: 281216.00

# %% [markdown]
# ## Задача 4. Арифметика

# %% [markdown]
# **Условие.** Создайте программу, которая запрашивает у пользователя два целых числа a и b, после чего выводит на экран результаты следующих математических операций:
# * сумма a и b;
# * разница между a и b;
# * произведение a и b;
# * частное от деления a на b;
# * остаток от деления a на b;
# * десятичный логарифм числа a;
# * результат возведения числа a в степень b.

# %%
#свое решение
from math import log10 as log
a = int(input('введи 1е целое цисло: '))
b = int(input('введи 2е целое цисло: '))
print('сумма чисел: ', a + b)
print('разница чисел: ', a - b)
print('произведение чисел: ', a * b)
print('деление чисел: ', a / b)
print('остаток от деления чисел: ', a % b)
print('десятичный логарифм 1го числа: ', log(a))
print('возведение 1 числа в степень второго числа: ', a ** b)
# Out:
# введи 1е целое цисло: 4
# введи 2е целое цисло: 5
# сумма чисел:  9
# разница чисел:  -1
# произведение чисел:  20
# деление чисел:  0.8
# остаток от деления чисел:  4
# десятичный логарифм 1го числа:  0.6020599913279624
# возведение 1 числа в степень второго числа:  1024

# %% [markdown]
# ## Задача 5. Размен

# %% [markdown]
# **Условие.** Представьте, что вы пишете программное обеспечение для автоматической кассы в  магазине самообслуживания. Одной из функций, заложенных в кассу, должен быть расчет сдачи в случае оплаты покупателем наличными.
# Напишите программу, которая будет запрашивать у пользователя сумму сдачи в копейках. После этого она должна рассчитать и вывести на экран, сколько и каких монет потребуется для выдачи указанной суммы, при условии что должно быть задействовано минимально возможное количество монет. Допустим, у нас есть в распоряжении монеты достоинством в 1, 5, 10, 50 копеек, а также в 1, 2 и 5 рублей.

# %%
#свое решение
n = float(input('сумма в копейках: '))
n500 = n / 500
n = n % 500

n200 = n / 200
n = n % 200

n100 = n / 100
n = n % 100

n50 = n / 50
n = n % 50

n10 = n / 10
n = n % 10

n5 = n / 5
n = n % 5

print('Сумма сдачи будет составлять: %02d - 5 рублевых монет, %02d - 2 рублевых монет, %02d - 1 рублевых монет, %02d -  50 копеешных монет, %02d - 10 копеешных монет, %02d - 5 копеешных монет, %02d - 1 копеешных монет' % (n500, n200, n100, n50, n10, n5, n))
# Out:
# сумма в копейках: 721
# Сумма сдачи будет составлять: 01 - 5 рублевых монет, 01 - 2 рублевых монет, 00 - 1 рублевых монет, 00 -  50 копеешных монет, 02 - 10 копеешных монет, 00 - 5 копеешных монет, 01 - 1 копеешных монет

# %% [markdown]
# ## Задача 6. Вчерашний хлеб

# %% [markdown]
# **Условие.** Пекарня продает хлеб по 49 рублей за буханку. Скидка на вчерашний хлеб составляет 60 %. Напишите программу, которая будет запрашивать у пользователя количество приобретенных вчерашних буханок хлеба. В вывод на экран должны быть включены обычная цена за буханку, цена со скидкой и общая стоимость приобретенного хлеба. Все значения должны быть выведены на отдельных строках с соответствующими описаниями. Используйте для вывода формат с двумя знаками после запятой и 5-ю знакоместами.

# %%
#Напишите свое решение
price = 49
discount = 60
price_with_discount = price - (price * (discount/100))
bulki = int(input("сколько приобрели вчерашних буханок хлеба: "))
print('%.2f %5s' % (price, '- цена за буханку'))
print('%.2f %5s' % (price_with_discount, '- цена со скидкой'))
print('%.2f %5s' % (price_with_discount * bulki, '- итог к оплате'))
# Out:
# сколько приобрели вчерашних буханок хлеба: 7
# 49.00 - цена за буханку
# 19.60 - цена со скидкой
# 137.20 - итог к оплате
